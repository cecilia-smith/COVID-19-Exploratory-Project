# %%
import pandas as pd
import numpy as np

pd.set_option("display.max_rows", 6)

# %%
covid_data = pd.read_csv('Indicators_of_Reduced_Access_to_Care_Due_to_the_Coronavirus_Pandemic_During_Last_4_Weeks.csv')

# %%
covid_data.head()
# Out:
#    Phase                           Indicator  ... Confidence Interval Quartile Range
# 0      1  Delayed Medical Care, Last 4 Weeks  ...         38.1 - 39.4            NaN
# 1      1  Delayed Medical Care, Last 4 Weeks  ...         32.5 - 37.2            NaN
# 2      1  Delayed Medical Care, Last 4 Weeks  ...         35.6 - 39.0            NaN
# 3      1  Delayed Medical Care, Last 4 Weeks  ...         39.0 - 41.7            NaN
# 4      1  Delayed Medical Care, Last 4 Weeks  ...         39.3 - 42.2            NaN
#
# [5 rows x 12 columns]

# %%
covid_by_race = covid_data.groupby(['Indicator','Group'])
covid_by_race['Value'].agg('mean').sort_values(ascending=False).head()
# Out:
# Indicator                                  Group
# Delayed or Did Not Get Care, Last 4 Weeks  By Race/Hispanic ethnicity    43.637500
#                                            National Estimate             42.975000
#                                            By Gender                     42.840625
#                                            By Education                  42.401562
#                                            By State                      42.355392
# Name: Value, dtype: float64

# %%
import plotly
import plotly.express as px
fig = px.scatter(covid_data, x = 'Week Label' , y = 'Value', title='Values as Weeks Pass')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="63554fad-d314-40cd-8c19-9c03c0dd3e5b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("63554fad-d314-40cd-8c19-9c03c0dd3e5b")) {
#                     Plotly.newPlot(
#                         '63554fad-d314-40cd-8c19-9c03c0dd3e5b',
# ...
